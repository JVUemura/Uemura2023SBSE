# %%
import pandas as pd
import matplotlib.pyplot as plt

dataCurrent = {'PQ':pd.read_csv("csvs/PQ_current.csv"),
               'Te':pd.read_csv("csvs/Te_current.csv"),
               'Wrm':pd.read_csv("csvs/Wrm_current.csv"),
               'I':pd.read_csv("csvs/I_current.csv"),
               'V':pd.read_csv("csvs/V_current.csv"),
               'Vcc':pd.read_csv("csvs/Vcc_current.csv")}

dataVoltage = {'PQ':pd.read_csv("csvs/PQ_voltage.csv"),
               'Te':pd.read_csv("csvs/Te_voltage.csv"),
               'Wrm':pd.read_csv("csvs/Wrm_voltage.csv"),
               'I':pd.read_csv("csvs/I_voltage.csv"),
               'V':pd.read_csv("csvs/V_voltage.csv"),
               'Vcc':pd.read_csv("csvs/Vcc_voltage.csv")}

# %%
# Declaração da Figura:
fig, [ax1, ax2] = plt.subplots(2, 1, sharex=True)
fig.set_size_inches(8, 6)

# Plots:
ax1.plot(dataVoltage["PQ"]["time"], dataVoltage["PQ"]["voltageSource.S.re"],
         label="Voltage control", color='r')
ax1.plot(dataCurrent["PQ"]["time"], dataCurrent["PQ"]["voltageSource.S.re"], 
         label="Current control", color='b', linestyle='-.')

ax1.set(xlabel='',    ylabel='$P_g$ $(pu)$')

ax2.plot(dataVoltage["PQ"]["time"], dataVoltage["PQ"]["voltageSource.S.im"], 
         label="Voltage control", color='r')
ax2.plot(dataCurrent["PQ"]["time"], dataCurrent["PQ"]["voltageSource.S.im"], 
         label="Current control", color='b', linestyle='-.')

ax2.set(xlabel='tempo (s)',    ylabel='$Q_g$ $(pu)$')

ax1.grid(True, linestyle='dotted')
ax2.grid(True, linestyle='dotted')

ax1.legend(loc='upper right')
plt.show()

fig.savefig("PQg.pdf", bbox_inches='tight', pad_inches=0)

# %%
# Declaração da Figura:
fig, [ax1, ax2] = plt.subplots(2, 1, sharex=True)
fig.set_size_inches(8, 6)

# Plots:
ax1.plot(dataVoltage["Te"]["time"], dataVoltage["Te"]["dfig_wt.mIT_fm.Te"], 
         label="Voltage control", color='r')
ax1.plot(dataCurrent["Te"]["time"], dataCurrent["Te"]["dfig_wt.mIT_fm.Te"], 
         label="Current control", color='b', linestyle='-.')
ax1.set(xlabel='',    ylabel='$T_e$ $(pu)$')

ax2.plot(dataVoltage["Wrm"]["time"], dataVoltage["Wrm"]["dfig_wt.mIT_fm.Wrm"], 
         label="Voltage control", color='r')
ax2.plot(dataCurrent["Wrm"]["time"], dataCurrent["Wrm"]["dfig_wt.mIT_fm.Wrm"], 
         label="Current control", color='b', linestyle='-.')

ax2.set(xlabel='tempo (s)',    ylabel='$\omega_{rm}$ $(pu)$')

ax1.grid(True, linestyle='dotted')
ax2.grid(True, linestyle='dotted')

ax1.legend(loc='upper right')
plt.show()

# fig.savefig("/content/drive/MyDrive/IC/grafics/clagtee2/Psr.pdf", bbox_inches='tight', pad_inches=0)

# %%
# Declaração da Figura:
fig, [ax1, ax2, ax3, ax4] = plt.subplots(4, 1, sharex=True)
fig.set_size_inches(8, 6)

# Plots:
ax1.plot(dataVoltage["I"]["time"], dataVoltage["I"]["dfig_wt.conversor.controlledVoltageSourceR.i.re"], 
         label="Voltage control", color='r')

ax1.plot(dataCurrent["I"]["time"], dataCurrent["I"]["dfig_wt.conversor.currRSC.i.re"], 
         label="Current control", color='b', linestyle='-.')

ax1.set(xlabel='',    ylabel='$I_{qr}$ $(pu)$')

ax2.plot(dataVoltage["I"]["time"], dataVoltage["I"]["dfig_wt.conversor.controlledVoltageSourceR.i.im"], 
         label="Voltage control", color='r')

ax2.plot(dataCurrent["I"]["time"], dataCurrent["I"]["dfig_wt.conversor.currRSC.i.im"], 
         label="Current control", color='b', linestyle='-.')

ax2.set(xlabel='',    ylabel='$I_{dr}$ $(pu)$')

ax3.plot(dataVoltage["I"]["time"], dataVoltage["I"]["dfig_wt.conversor.controlledVoltageSourceG.i.re"], 
         label="Voltage control", color='r')

ax3.plot(dataCurrent["I"]["time"], dataCurrent["I"]["dfig_wt.conversor.currGSC.i.re"], 
         label="Current control", color='b', linestyle='-.')

ax3.set(xlabel='',    ylabel='$I_{qg}$ $(pu)$')

ax4.plot(dataVoltage["I"]["time"], dataVoltage["I"]["dfig_wt.conversor.controlledVoltageSourceG.i.im"], 
         label="Voltage control", color='r')

ax4.plot(dataCurrent["I"]["time"], dataCurrent["I"]["dfig_wt.conversor.currGSC.i.im"], 
         label="Current control", color='b', linestyle='-.')

ax4.set(xlabel='tempo (s)',    ylabel='$I_{dg}$ $(pu)$')

ax1.grid(True, linestyle='dotted')
ax2.grid(True, linestyle='dotted')
ax3.grid(True, linestyle='dotted')
ax4.grid(True, linestyle='dotted')

ax1.legend(loc='upper right')
plt.show()

# fig.savefig("/content/drive/MyDrive/IC/grafics/clagtee2/Psr.pdf", bbox_inches='tight', pad_inches=0)

# %%
# Declaração da Figura:
fig, [ax1, ax2, ax3, ax4] = plt.subplots(4, 1, sharex=True)
fig.set_size_inches(8, 6)

# Gráfico 1::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::
ax1.plot(dataVoltage["I"]["time"], dataVoltage["V"]["dfig_wt.conversor.controlledVoltageSourceR.v.re"], 
         label="Voltage control", color='r')
ax1.plot(dataCurrent["I"]["time"], dataCurrent["V"]["dfig_wt.conversor.currRSC.v.re"], 
         label="Current control", color='b', linestyle='-.')
ax1.set(xlabel='',    ylabel='$V_{qr}$ $(pu)$')
ax1.grid(True, linestyle='dotted')
ax1.legend(loc='upper right')

# Gráfico 2::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::
ax2.plot(dataVoltage["I"]["time"], dataVoltage["V"]["dfig_wt.conversor.controlledVoltageSourceR.v.im"], 
         label="Voltage control", color='r')
ax2.plot(dataCurrent["I"]["time"], dataCurrent["V"]["dfig_wt.conversor.currRSC.v.im"], 
         label="Current control", color='b', linestyle='-.')
ax2.set(xlabel='',    ylabel='$V_{dr}$ $(pu)$')
ax2.grid(True, linestyle='dotted')

# Gráfico 3::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::
ax3.plot(dataVoltage["I"]["time"], dataVoltage["V"]["dfig_wt.conversor.controlledVoltageSourceG.v.re"], 
         label="Voltage control", color='r')
ax3.plot(dataCurrent["I"]["time"], dataCurrent["V"]["dfig_wt.conversor.currGSC.v.re"], 
         label="Current control", color='b', linestyle='-.')
ax3.set(xlabel='',    ylabel='$V_{qg}$ $(pu)$')
ax3.grid(True, linestyle='dotted')

# Gráfico 4::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::
ax4.plot(dataVoltage["I"]["time"], dataVoltage["V"]["dfig_wt.conversor.controlledVoltageSourceG.v.im"], 
         label="Voltage control", color='r')
ax4.plot(dataCurrent["I"]["time"], dataCurrent["V"]["dfig_wt.conversor.currGSC.v.im"], 
         label="Current control", color='b', linestyle='-.')
ax4.set(xlabel='tempo (s)',    ylabel='$V_{dg}$ $(pu)$')
ax4.grid(True, linestyle='dotted')

plt.show()

# %%
# Declaração da Figura:
fig, ax1 = plt.subplots(1, 1, sharex=True)
fig.set_size_inches(8, 3)

# Plots:
ax1.plot(dataVoltage["Vcc"]["time"], dataVoltage["Vcc"]["dfig_wt.conversor.capacitor.v"], 
         label="Voltage control", color='r')
ax1.plot(dataCurrent["Vcc"]["time"], dataCurrent["Vcc"]["dfig_wt.conversor.capacitor.v"], 
         label="Current control", color='b', linestyle='-.')
ax1.set(xlabel='',    ylabel='$V_{cc}$ $(pu)$')

ax1.grid(True, linestyle='dotted')

ax1.legend(loc='upper right')
plt.show()

# fig.savefig("/content/drive/MyDrive/IC/grafics/clagtee2/Psr.pdf", bbox_inches='tight', pad_inches=0)
